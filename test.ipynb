# %%
from ultralytics import YOLO
import cv2

model = YOLO(r"C:\Users\enjoykubphom\Documents\car_detection\runs\best.pt")

results = model.predict(r"C:\Users\enjoykubphom\Documents\car_detection\dataset\test\images\Image_39_jpg.rf.a334d068524f740d0598bb641f186fa1.jpg", conf=0.5, save=True)

for result in results:
    result.show()
# Out:
# image 1/1 C:\Users\enjoykubphom\Documents\car_detection\dataset\test\images\Image_39_jpg.rf.a334d068524f740d0598bb641f186fa1.jpg: 1024x1024 1 Cars, 1 Ford, 28.8ms
# Speed: 7.6ms preprocess, 28.8ms inference, 6.0ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to C:\Users\enjoykubphom\Documents\car_detection\runs\detect\predict3
